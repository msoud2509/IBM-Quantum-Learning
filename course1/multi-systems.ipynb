# %%
# ensure qiskit is properly installed
from qiskit import __version__
print(f'Qiskit version: {__version__}')

from qiskit.quantum_info import Statevector, Operator
from qiskit.visualization import plot_histogram

from numpy import sqrt
# Out:
# Qiskit version: 2.4.1

# %%
zero = Statevector.from_label('0')
one = Statevector.from_label('1')
psi = zero.tensor(one)
display(psi.draw('latex'))

minus_i = Statevector.from_label('l')
plus = Statevector.from_label('+')
phi = plus.tensor(minus_i)

# below two should be the same (^ is the tensor product operator)
display(phi.draw('latex'))
display((plus ^ minus_i).draw('latex'))
# Out:
# $$ |01\rangle$$
# $$\frac{1}{2} |00\rangle- \frac{i}{2} |01\rangle+\frac{1}{2} |10\rangle- \frac{i}{2} |11\rangle$$
# $$\frac{1}{2} |00\rangle- \frac{i}{2} |01\rangle+\frac{1}{2} |10\rangle- \frac{i}{2} |11\rangle$$

# %%
H = Operator.from_label("H")
Id = Operator.from_label("I")
X = Operator.from_label("X")
display(H.tensor(Id).draw("latex"))
display((H ^ Id ^ X).draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & \frac{\sqrt{2}}{2} & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & 0 & - \frac{\sqrt{2}}{2} & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# $$
#
# \begin{bmatrix}
# 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0  \\
#  \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0  \\
#  0 & 0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2} & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2}}{2} & 0 & 0  \\
#  \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2}}{2} & 0 & 0 & 0  \\
#  0 & 0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2}}{2}  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2}}{2} & 0  \\
#  \end{bmatrix}
# $$

# %%
w = Statevector([0, 1, 1, 0, 1, 0, 0, 0] / sqrt(3))
display(w.draw("latex"))

result, state = w.measure([0])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))

result, state = w.measure([0, 1])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))

# measure all at once
display(plot_histogram(w.sample_counts(1000)))

# probability when measuring just the first qubit
display(plot_histogram(w.sample_counts(1000, qargs=[0])))
# Out:
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$
# Measured: 1
# State after measurement:
# $$ |001\rangle$$
# Measured: 01
# State after measurement:
# $$ |001\rangle$$
